# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import joblib
import imodelsx.process_results
import sys
sys.path.append('../experiments/')
results_dir = '../results/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Load the results into a pandas dataframe

# %%
r = imodelsx.process_results.get_results_df(results_dir)
experiment_filename = '../experiments/01_eval.py'
r = imodelsx.process_results.fill_missing_args_with_default(
    r, experiment_filename)

r = r[['acc_val'] + [c for c in r.columns if not c == 'acc_val']]
r = r.sort_values('acc_val', ascending=False)
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 4296.91it/s]

# %%
# color the acc_val column
display(
    r
    .style
    .background_gradient(
        cmap='viridis', subset=['acc_val']
    )
    .format(precision=2)
)
# Out:
# <style type="text/css">
# #T_ab858_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ab858_row1_col0 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_ab858_row2_col0, #T_ab858_row3_col0 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_ab858_row4_col0, #T_ab858_row5_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_ab858_row6_col0, #T_ab858_row7_col0 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_ab858_row8_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_ab858_row9_col0, #T_ab858_row10_col0 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_ab858_row11_col0, #T_ab858_row12_col0 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_ab858_row13_col0, #T_ab858_row14_col0, #T_ab858_row15_col0, #T_ab858_row16_col0 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_ab858_row17_col0, #T_ab858_row18_col0 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_ab858_row19_col0, #T_ab858_row20_col0 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_ab858_row21_col0, #T_ab858_row22_col0 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_ab858_row23_col0, #T_ab858_row24_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab858">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab858_level0_col0" class="col_heading level0 col0" >acc_val</th>
#       <th id="T_ab858_level0_col1" class="col_heading level0 col1" >dataset_name</th>
#       <th id="T_ab858_level0_col2" class="col_heading level0 col2" >checkpoint</th>
#       <th id="T_ab858_level0_col3" class="col_heading level0 col3" >ngrams</th>
#       <th id="T_ab858_level0_col4" class="col_heading level0 col4" >use_all_ngrams</th>
#       <th id="T_ab858_level0_col5" class="col_heading level0 col5" >use_next_token_distr_embedding</th>
#       <th id="T_ab858_level0_col6" class="col_heading level0 col6" >embedding_string_prompt</th>
#       <th id="T_ab858_level0_col7" class="col_heading level0 col7" >zeroshot_strategy</th>
#       <th id="T_ab858_level0_col8" class="col_heading level0 col8" >seed</th>
#       <th id="T_ab858_level0_col9" class="col_heading level0 col9" >save_dir</th>
#       <th id="T_ab858_level0_col10" class="col_heading level0 col10" >use_cache</th>
#       <th id="T_ab858_level0_col11" class="col_heading level0 col11" >batch_size</th>
#       <th id="T_ab858_level0_col12" class="col_heading level0 col12" >save_dir_unique</th>
#       <th id="T_ab858_level0_col13" class="col_heading level0 col13" >roc_val</th>
#       <th id="T_ab858_level0_col14" class="col_heading level0 col14" >acc_baseline</th>
#       <th id="T_ab858_level0_col15" class="col_heading level0 col15" >mean_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab858_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_ab858_row0_col0" class="data row0 col0" >0.63</td>
#       <td id="T_ab858_row0_col1" class="data row0 col1" >rotten_tomatoes</td>
#       <td id="T_ab858_row0_col2" class="data row0 col2" >hkunlp/instructor-xl</td>
#       <td id="T_ab858_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_ab858_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_ab858_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_ab858_row0_col6" class="data row0 col6" >instructor_sentiment</td>
#       <td id="T_ab858_row0_col7" class="data row0 col7" >pos_class</td>
#       <td id="T_ab858_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_ab858_row0_col9" class="data row0 col9" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_ab858_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_ab858_row0_col11" class="data row0 col11" >8</td>
#       <td id="T_ab858_row0_col12" class="data row0 col12" >/home/chansingh/augmented-interpretable-models/augdistill/results/bd5ac3875c805a0e67a5b648fcc59e0a0b5e9abff5d469fc5f2b244c3496c6db</td>
#       <td id="T_ab858_row0_col13" class="data row0 col13" >0.62</td>
#       <td id="T_ab858_row0_col14" class="data row0 col14" >0.49</td>
#       <td id="T_ab858_row0_col15" class="data row0 col15" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_ab858_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_ab858_row1_col0" class="data row1 col0" >0.59</td>
#       <td id="T_ab858_row1_col1" class="data row1 col1" >rotten_tomatoes</td>
#       <td id="T_ab858_row1_col2" class="data row1 col2" >textattack/distilbert-base-uncased-rotten-tomatoes</td>
#       <td id="T_ab858_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_ab858_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_ab858_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_ab858_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_ab858_row1_col7" class="data row1 col7" >pos_class</td>
#       <td id="T_ab858_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_ab858_row1_col9" class="data row1 col9" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_ab858_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_ab858_row1_col11" class="data row1 col11" >8</td>
#       <td id="T_ab858_row1_col12" class="data row1 col12" >/home/chansingh/augmented-interpretable-models/augdistill/results/1a41b8dab1b5bfe4b08cfa3ba9d1ed0736b56e39780cda131d231d1af44afc64</td>
#       <td id="T_ab858_row1_col13" class="data row1 col13" >0.62</td>
#       <td id="T_ab858_row1_col14" class="data row1 col14" >0.49</td>
#       <td id="T_ab858_row1_col15" class="data row1 col15" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_ab858_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab858_row2_col0" class="data row2 col0" >0.55</td>
#       <td id="T_ab858_row2_col1" class="data row2 col1" >rotten_tomatoes</td>
#       <td id="T_ab858_row2_col2" class="data row2 col2" >meta-llama/Llama-2-7b-hf</td>
#       <td id="T_ab858_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_ab858_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_ab858_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ab858_row2_col6" class="data row2 col6" >synonym</td>
#       <td id="T_ab858_row2_col7" class="data row2 col7" >pos_class</td>
#       <td id="T_ab858_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_ab858_row2_col9" class="data row2 col9" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_ab858_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_ab858_row2_col11" class="data row2 col11" >8</td>
#       <td id="T_ab858_row2_col12" class="data row2 col12" >/home/chansingh/augmented-interpretable-models/augdistill/results/0f62167b4ec16d0a661a7ca02177350ac82d1743cfe92c39ef9fdd82bda804dd</td>
#       <td id="T_ab858_row2_col13" class="data row2 col13" >0.53</td>
#       <td id="T_ab858_row2_col14" class="data row2 col14" >0.49</td>
#       <td id="T_ab858_row2_col15" class="data row2 col15" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_ab858_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_ab858_row3_col0" class="data row3 col0" >0.55</td>
#       <td id="T_ab858_row3_col1" class="data row3 col1" >rotten_tomatoes</td>
#       <td id="T_ab858_row3_col2" class="data row3 col2" >meta-llama/Llama-2-7b-hf</td>
#       <td id="T_ab858_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_ab858_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_ab858_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_ab858_row3_col6" class="data row3 col6" >synonym</td>
#       <td id="T_ab858_row3_col7" class="data row3 col7" >difference</td>
#       <td id="T_ab858_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_ab858_row3_col9" class="data row3 col9" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_ab858_row3_col10" class="data row3 col10" >1</td>
#       <td id="T_ab858_row3_col11" class="data row3 col11" >8</td>
#       <td id="T_ab858_row3_col12" class="data row3 col12" >/home/chansingh/augmented-interpretable-models/augdistill/results/d7868b
