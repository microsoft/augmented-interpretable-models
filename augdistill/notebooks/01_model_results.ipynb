# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import joblib
import imodelsx.process_results
import sys
sys.path.append('../experiments/')
results_dir = '../results/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Load the results into a pandas dataframe

# %%
r = imodelsx.process_results.get_results_df(results_dir)
experiment_filename = '../experiments/01_eval.py'
r = imodelsx.process_results.fill_missing_args_with_default(
    r, experiment_filename)

r = r[['acc_val', 'roc_val'] +
      [c for c in r.columns if not c in ['acc_val', 'roc_val']]]
r = r.sort_values(by=['acc_val', 'roc_val'], ascending=False)
# Out:
# 100%|██████████| 38/38 [00:00<00:00, 4397.39it/s]

# %%
# highlight the entire rows in blue where use_next_token_distr_embedding=1
# color the acc_val column
display(
    r
    .style
    # .applymap(
    #     lambda x: 'background-color: gray' if x == 1 else '',
    #     subset=['use_next_token_distr_embedding']
    # )
    .background_gradient(
        cmap='viridis', subset=['acc_val', 'roc_val']
    )
    .format(precision=2)
)  # .to_html('results.html')
# Out:
# <style type="text/css">
# #T_9014f_row0_col0, #T_9014f_row0_col1, #T_9014f_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9014f_row1_col0 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_9014f_row2_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_9014f_row2_col1 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_9014f_row3_col0, #T_9014f_row4_col0 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_9014f_row3_col1, #T_9014f_row4_col1, #T_9014f_row34_col1, #T_9014f_row35_col1 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_9014f_row5_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_9014f_row5_col1, #T_9014f_row6_col1, #T_9014f_row7_col1 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_9014f_row6_col0, #T_9014f_row7_col0, #T_9014f_row8_col0, #T_9014f_row9_col0, #T_9014f_row10_col0, #T_9014f_row11_col0, #T_9014f_row12_col0, #T_9014f_row13_col0, #T_9014f_row14_col0, #T_9014f_row15_col0, #T_9014f_row16_col0, #T_9014f_row17_col0, #T_9014f_row18_col0, #T_9014f_row19_col0, #T_9014f_row20_col0, #T_9014f_row21_col0, #T_9014f_row22_col0, #T_9014f_row23_col0, #T_9014f_row24_col0, #T_9014f_row25_col0, #T_9014f_row26_col0, #T_9014f_row27_col0, #T_9014f_row28_col0, #T_9014f_row29_col0, #T_9014f_row30_col0, #T_9014f_row31_col0 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_9014f_row8_col1, #T_9014f_row9_col1, #T_9014f_row10_col1, #T_9014f_row11_col1, #T_9014f_row12_col1, #T_9014f_row13_col1, #T_9014f_row14_col1, #T_9014f_row15_col1, #T_9014f_row16_col1, #T_9014f_row17_col1, #T_9014f_row18_col1, #T_9014f_row19_col1, #T_9014f_row20_col1, #T_9014f_row21_col1, #T_9014f_row22_col1, #T_9014f_row23_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_9014f_row24_col1, #T_9014f_row25_col1, #T_9014f_row26_col1, #T_9014f_row27_col1 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_9014f_row28_col1, #T_9014f_row29_col1 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_9014f_row30_col1, #T_9014f_row31_col1 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_9014f_row32_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_9014f_row32_col1 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_9014f_row33_col0 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_9014f_row33_col1 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_9014f_row34_col0, #T_9014f_row35_col0 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_9014f_row36_col0, #T_9014f_row36_col1, #T_9014f_row37_col0, #T_9014f_row37_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9014f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9014f_level0_col0" class="col_heading level0 col0" >acc_val</th>
#       <th id="T_9014f_level0_col1" class="col_heading level0 col1" >roc_val</th>
#       <th id="T_9014f_level0_col2" class="col_heading level0 col2" >dataset_name</th>
#       <th id="T_9014f_level0_col3" class="col_heading level0 col3" >checkpoint</th>
#       <th id="T_9014f_level0_col4" class="col_heading level0 col4" >ngrams</th>
#       <th id="T_9014f_level0_col5" class="col_heading level0 col5" >use_all_ngrams</th>
#       <th id="T_9014f_level0_col6" class="col_heading level0 col6" >embedding_ngram_strategy</th>
#       <th id="T_9014f_level0_col7" class="col_heading level0 col7" >embedding_string_prompt</th>
#       <th id="T_9014f_level0_col8" class="col_heading level0 col8" >zeroshot_strategy</th>
#       <th id="T_9014f_level0_col9" class="col_heading level0 col9" >renormalize_embs_strategy</th>
#       <th id="T_9014f_level0_col10" class="col_heading level0 col10" >seed</th>
#       <th id="T_9014f_level0_col11" class="col_heading level0 col11" >save_dir</th>
#       <th id="T_9014f_level0_col12" class="col_heading level0 col12" >use_cache</th>
#       <th id="T_9014f_level0_col13" class="col_heading level0 col13" >batch_size</th>
#       <th id="T_9014f_level0_col14" class="col_heading level0 col14" >save_dir_unique</th>
#       <th id="T_9014f_level0_col15" class="col_heading level0 col15" >acc_baseline</th>
#       <th id="T_9014f_level0_col16" class="col_heading level0 col16" >mean_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9014f_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_9014f_row0_col0" class="data row0 col0" >0.63</td>
#       <td id="T_9014f_row0_col1" class="data row0 col1" >0.62</td>
#       <td id="T_9014f_row0_col2" class="data row0 col2" >rotten_tomatoes</td>
#       <td id="T_9014f_row0_col3" class="data row0 col3" >hkunlp/instructor-xl</td>
#       <td id="T_9014f_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_9014f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_9014f_row0_col6" class="data row0 col6" >mean</td>
#       <td id="T_9014f_row0_col7" class="data row0 col7" >instructor_sentiment</td>
#       <td id="T_9014f_row0_col8" class="data row0 col8" >pos_class</td>
#       <td id="T_9014f_row0_col9" class="data row0 col9" >StandardScaler</td>
#       <td id="T_9014f_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_9014f_row0_col11" class="data row0 col11" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_9014f_row0_col12" class="data row0 col12" >1</td>
#       <td id="T_9014f_row0_col13" class="data row0 col13" >16</td>
#       <td id="T_9014f_row0_col14" class="data row0 col14" >/home/chansingh/augmented-interpretable-models/augdistill/results/bd5ac3875c805a0e67a5b648fcc59e0a0b5e9abff5d469fc5f2b244c3496c6db</td>
#       <td id="T_9014f_row0_col15" class="data row0 col15" >0.49</td>
#       <td id="T_9014f_row0_col16" class="data row0 col16" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_9014f_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_9014f_row1_col0" class="data row1 col0" >0.59</td>
#       <td id="T_9014f_row1_col1" class="data row1 col1" >0.62</td>
#       <td id="T_9014f_row1_col2" class="data row1 col2" >rotten_tomatoes</td>
#       <td id="T_9014f_row1_col3" class="data row1 col3" >textattack/distilbert-base-uncased-rotten-tomatoes</td>
#       <td id="T_9014f_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_9014f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_9014f_row1_col6" class="data row1 col6" >mean</td>
#       <td id="T_9014f_row1_col7" class="data row1 col7" >None</td>
#       <td id="T_9014f_row1_col8" class="data row1 col8" >pos_class</td>
#       <td id="T_9014f_row1_col9" class="data row1 col9" >StandardScaler</td>
#       <td id="T_9014f_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_9014f_row1_col11" class="data row1 col11" >/home/chansingh/augmented-interpretable-models/augdistill/results</td>
#       <td id="T_9014f_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_9014f_row1_col13" class="data row1 col13" >64</td>
#       <td id="T_9014f_row1_col14" class="data row1 col14" >/home/chansingh/augmented-interpretable-models/augdistill/results/1a41b8dab1b5bfe4b08cfa3ba9d1ed0736b56e39780cda131d231d1af44afc64</td>
#       <td id="T_9014f_row1_col15" class="data row1 col15" >0.49</td>
#       <td id="T_9014f_row1_col16" class="data row1 col16" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_9014f_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_9014f_row2_col0" class="data row2 col0" >0.58</td>
#       <td id="T_9014f_row2_col1" class="data row2 col1" >0.57</td>
#       <td id="T_9014f_row2_col2" class="data row2 col2" >rotten_tomatoes</td>
#       <td id="T_9014f_row2_col3" class="data row2 col3" >textattack/distilbert-base-uncased-rotten-tomatoes</td>
#       <td id="T_9014f_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_9014f_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_9014f_row2_col6" class="data row2 col6" >mean</td>
#       <td id="T_9014f_row2_col7" class="data row2 col7" >None</td>
#       <td id="T_9014f_row2_col8" class="data row2 col8" >pos_class</td>
#       <td id="T_9014f_row2_col9" class="data row2 col9" >QuantileTransformer</td>
#       <td id="T_9014f_row2_col10" class="data
